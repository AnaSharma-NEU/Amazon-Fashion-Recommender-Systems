# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import math
import json
import time
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import NearestNeighbors
import scipy.sparse
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds
import warnings; warnings.simplefilter('ignore')
# %matplotlib inline

# %%
# import os
# import csv
# cwd= os.getcwd()    #present directory
# print('Current working directory:', cwd) 
# os.chdir('/Users/Advance/Downloads')


# with open('AmazonFashion.csv', 'r') as file:
#     reader = csv.DictReader(file)
#     for row in reader:
#         print(dict(row))
#         print("\n")
 
import pandas as pd

amazon = pd.read_csv("C:/Users/Advance/Downloads/AmazonFashion.csv")
amazon.head(10)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521
# 1        2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2        4     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3        2      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 4        3     False  07 27, 2014   A89F3LQADZBS5  7106116521
# 5        5      True  07 19, 2014  A29HLOUW0NS0EH  7106116521
# 6        4      True  05 31, 2014   A7QS961ROI6E0  7106116521
# 7        3      True  09 22, 2013  A1BB77SEBQT8VX  B00007GDFV
# 8        3      True  07 17, 2013   AHWOW7D1ABO9C  B00007GDFV
# 9        3      True  04 13, 2013   AKS3GULZE0HFC  B00007GDFV
#
#          reviewerName                                         reviewText  \
# 0               Tracy                             Exactly what I needed.
# 1           Sonja Lau  I agree with the other review, the opening is ...
# 2            Kathleen  Love these... I am going to order another pack...
# 3         Jodi Stoner                                too tiny an opening
# 4        Alexander D.                                               Okay
# 5   Patricia R. Erwin                             Exactly what I wanted.
# 6    REBECCA S LAYTON  These little plastic backs work great.  No mor...
# 7  Darrow H Ankrum II  mother - in - law wanted it as a present for h...
# 8              rosieO  Item is of good quality. Looks great, too. But...
# 9          M. Waltman  I had used my last el-cheapo fake leather ciga...
#
#                                              summary  unixReviewTime  vote  \
# 0                             perfect replacements!!      1413763200   NaN
# 1  I agree with the other review, the opening is ...      1411862400   3.0
# 2                                My New 'Friends' !!      1408924800   NaN
# 3                                          Two Stars      1408838400   NaN
# 4                                        Three Stars      1406419200   NaN
# 5                                         Five Stars      1405728000   NaN
# 6                                       Works great!      1401494400   NaN
# 7                                bought as a present      1379808000   NaN
# 8                          Buxton heiress collection      1374019200   NaN
# 9                     Top Clasp Broke Within 3 days!      1365811200   NaN
#
#    ... image/6 image/7 image/8 image/9 image/10 image/11 image/12 image/13  \
# 0  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 1  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 2  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 3  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 4  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 5  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 6  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 7  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 8  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 9  ...     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
#
#   style/Size Name: style/Style:
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# 5              NaN          NaN
# 6              NaN          NaN
# 7              NaN          NaN
# 8              NaN          NaN
# 9              NaN          NaN
#
# [10 rows x 29 columns]

# %%
#Shape of the data
amazon.shape
# Out:
# (19999, 29)

# %%
#Taking subset of the dataset
amazon=amazon.iloc[:1048576,0:]

# %%
#Check the datatypes
amazon.dtypes
amazon.info()
# Out:
# overall                int64
# verified                bool
# reviewTime            object
# reviewerID            object
# asin                  object
# reviewerName          object
# reviewText            object
# summary               object
# unixReviewTime         int64
# vote                 float64
# style/Color:          object
# style/Size:           object
# image/0               object
# style/Metal Type:     object
# image/1               object
# image/2               object
# image/3               object
# image/4               object
# image/5               object
# image/6               object
# image/7               object
# image/8               object
# image/9               object
# image/10              object
# image/11              object
# image/12              object
# image/13              object
# style/Size Name:      object
# style/Style:          object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   overall            19999 non-null  int64
#  1   verified           19999 non-null  bool
#  2   reviewTime         19999 non-null  object
#  3   reviewerID         19999 non-null  object
#  4   asin               19999 non-null  object
#  5   reviewerName       19996 non-null  object
#  6   reviewText         19975 non-null  object
#  7   summary            19993 non-null  object
#  8   unixReviewTime     19999 non-null  int64
#  9   vote               1412 non-null   float64
#  10  style/Color:       11835 non-null  object
#  11  style/Size:        11933 non-null  object
#  12  image/0            303 non-null    object
#  13  style/Metal Type:  3 non-null      object
#  14  image/1            75 non-null     object
#  15  image/2            25 non-null     object
#  16  image/3            13 non-null     object
#  17  image/4            5 non-null      object
#  18  image/5            4 non-null      object
#  19  image/6            2 non-null      object
#  20  image/7            2 non-null      object
#  21  image/8            2 non-null      object
#  22  image/9            1 non-null      object
#  23  image/10           1 non-null      object
#  24  image/11           1 non-null      object
#  25  image/12           1 non-null      object
#  26  image/13           1 non-null      object
#  27  style/Size Name:   3289 non-null   object
#  28  style/Style:       3340 non-null   object
# dtypes: bool(1), float64(1), int64(2), object(25)
# memory usage: 4.3+ MB

# %%
#Five point summary 

amazon.describe()['overall'].T
# Out:
# count    19999.000000
# mean         4.294015
# std          1.144854
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: overall, dtype: float64

# %%
#to find max and min rating
MAX = amazon.overall.max()
print("Maximum rating is",MAX)
MIN = amazon.overall.min()
print("Minimum rating is",MIN)
# Out:
# Maximum rating is 5
# Minimum rating is 1

# %%
#Check for missing values
print('Number of missing values across columns: \n',amazon.isnull().sum())
# Out:
# Number of missing values across columns:
#  overall                  0
# verified                 0
# reviewTime               0
# reviewerID               0
# asin                     0
# reviewerName             3
# reviewText              24
# summary                  6
# unixReviewTime           0
# vote                 18587
# style/Color:          8164
# style/Size:           8066
# image/0              19696
# style/Metal Type:    19996
# image/1              19924
# image/2              19974
# image/3              19986
# image/4              19994
# image/5              19995
# image/6              19997
# image/7              19997
# image/8              19997
# image/9              19998
# image/10             19998
# image/11             19998
# image/12             19998
# image/13             19998
# style/Size Name:     16710
# style/Style:         16659
# dtype: int64

# %%
Amazon_F = amazon [["overall","verified","reviewTime","reviewerID","asin","reviewerName","reviewText","summary","unixReviewTime","vote"]]
Amazon_F
# Out:
#        overall  verified   reviewTime      reviewerID        asin  \
# 0            5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521
# 1            2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2            4     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3            2      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 4            3     False  07 27, 2014   A89F3LQADZBS5  7106116521
# ...        ...       ...          ...             ...         ...
# 19994        5      True  08 23, 2013  A2I8U2L6ZOLPP9  B000P0X15G
# 19995        5     False  08 22, 2013  A38SLX4EMMLSTL  B000P0X15G
# 19996        5      True  08 21, 2013  A24NGH58L8CWDT  B000P0X15G
# 19997        5      True  08 20, 2013  A1NJ9OSQZOZB02  B000P0X15G
# 19998        5      True  08 20, 2013  A2Y39N7FDHEPNY  B000P0X15G
#
#           reviewerName                                         reviewText  \
# 0                Tracy                             Exactly what I needed.
# 1            Sonja Lau  I agree with the other review, the opening is ...
# 2             Kathleen  Love these... I am going to order another pack...
# 3          Jodi Stoner                                too tiny an opening
# 4         Alexander D.                                               Okay
# ...                ...                                                ...
# 19994          Hmama65  My son and daughter-in -law were vacationing i...
# 19995               LC  We loved this hat. Baby looked super cute but ...
# 19996   Veronica Jones  I love the drawstring and the chin tie. Both m...
# 19997  argentinamazing  I got it for my 6 months old. He wore it all s...
# 19998       Bubble Gum  My daughter is 5 months and so I purchase clot...
#
#                                                  summary  unixReviewTime  vote
# 0                                 perfect replacements!!      1413763200   NaN
# 1      I agree with the other review, the opening is ...      1411862400   3.0
# 2                                    My New 'Friends' !!      1408924800   NaN
# 3                                              Two Stars      1408838400   NaN
# 4                                            Three Stars      1406419200   NaN
# ...                                                  ...             ...   ...
# 19994                             Awesome Sun Protection      1377216000   NaN
# 19995                                          Great hat      1377129600   NaN
# 19996                                  Great fitting hat      1377043200   NaN
# 19997                                              Great      1376956800   NaN
# 19998                                          Great hat      1376956800   NaN
#
# [19999 rows x 10 columns]

# %%
#Check for missing values
print('Number of missing values across columns: \n',Amazon_F.isnull().sum())
# Out:
# Number of missing values across columns:
#  overall               0
# verified              0
# reviewTime            0
# reviewerID            0
# asin                  0
# reviewerName          3
# reviewText           24
# summary               6
# unixReviewTime        0
# vote              18587
# dtype: int64

# %%
# Check the distribution of the rating
with sns.axes_style('white'):
    sns.set_theme(style="whitegrid")
    g = sns.factorplot("overall", data=Amazon_F, aspect=2.0,kind='count')
    g.set_ylabels("Total number of ratings")

# %%
# users Count based on ratings
for i in range(1,6):
  print('Number of users who rated {0} ratings = {1}'.format(i, Amazon_F[Amazon_F['overall'] == i].shape[0]))
# Out:
# Number of users who rated 1 ratings = 1078
# Number of users who rated 2 ratings = 973
# Number of users who rated 3 ratings = 1643
# Number of users who rated 4 ratings = 3602
# Number of users who rated 5 ratings = 12703

# %%
# Top 10 products based on rating
topmost_rated_products = Amazon_F.groupby('asin').size().sort_values(ascending=False)[:10]
topmost_rated_products
# Out:
# asin
# B000KPIHQ4    4365
# B000P0X15G    1758
# B000JOOR7O    1578
# B000GHRZN2    1408
# B000GHMRLW    1408
# B000K2PJ4K     936
# B000ER9V68     715
# B000NBIMG0     700
# B00062NHH0     641
# B000EE1NNA     536
# dtype: int64

# %%
#Corrplot
corr = Amazon_F.corr()
corr
# Out:
#                  overall  verified  unixReviewTime      vote
# overall         1.000000  0.003348        0.011286 -0.005030
# verified        0.003348  1.000000        0.315804 -0.006298
# unixReviewTime  0.011286  0.315804        1.000000 -0.094330
# vote           -0.005030 -0.006298       -0.094330  1.000000

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
#unique user and products
print("Total data ")
print("-"*50)
print("\nTotal no of ratings :",Amazon_F.shape[0])
print("Total No of Users   :", len(np.unique(Amazon_F.reviewerID)))
print("Total No of products  :", len(np.unique(Amazon_F.asin)))
# Out:
# Total data
# --------------------------------------------------
#
# Total no of ratings : 19999
# Total No of Users   : 18320
# Total No of products  : 141

# %%
#Number of rating per user
products_rated_per_user = Amazon_F.groupby(by='reviewerID')['overall'].count().sort_values(ascending=False)
products_rated_per_user.head(10)

#describing
products_rated_per_user.describe()
# Out:
# reviewerID
# A3W11493KS6Z2L    5
# ALJ66O1Y6SLHA     5
# A3I8S99J38ODC3    4
# A3IDT5LC91YJJU    4
# A27QAEYVW0V5FC    4
# A1C1NHT2ZZ5A4B    4
# A1IJDQ9PPIGA3P    4
# A6ILLZ8Y16XZV     4
# A3JBOS2369RWAS    4
# A1UF8LF658016W    4
# Name: overall, dtype: int64
# count    18320.000000
# mean         1.091648
# std          0.299491
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          5.000000
# Name: overall, dtype: float64

# %%
#quantile
quantiles = products_rated_per_user.quantile(np.arange(0,1.01,0.01), interpolation='higher')
quantiles
# Out:
# 0.00    1
# 0.01    1
# 0.02    1
# 0.03    1
# 0.04    1
#        ..
# 0.96    2
# 0.97    2
# 0.98    2
# 0.99    2
# 1.00    5
# Name: overall, Length: 101, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.title("Quantiles and Values")
quantiles.plot()
# quantiles with 0.05 difference
plt.scatter(x=quantiles.index[::5], y=quantiles.values[::5], c='green', label="quantiles with 0.05 intervals")
# quantiles with 0.25 difference
plt.scatter(x=quantiles.index[::25], y=quantiles.values[::25], c='Blue', label = "quantiles with 0.25 intervals")
plt.ylabel('No of ratings by Reviewer')
plt.xlabel('Value at the quantile')
plt.legend(loc='best')
plt.show()


print('\n No of rated product more than 5 per user : {}\n'.format(sum(products_rated_per_user >= 5)) )
# Out:
# Text(0.5, 1.0, 'Quantiles and Values')
# <AxesSubplot:title={'center':'Quantiles and Values'}>
# Text(0, 0.5, 'No of ratings by Reviewer')
# Text(0.5, 0, 'Value at the quantile')
#  No of rated product more than 5 per user : 2

# %%
user = Amazon_F.groupby('reviewerID')['asin'].count().sort_values(ascending=False).head(5)

plt.figure(figsize=(15,5))
user.plot(kind="bar", color="blue", alpha=0.5)
plt.title("Top 5 reviewerID according to products purchase", size=18, color='orange')
plt.xlabel('User Id', size=12)
plt.xticks(rotation=0)
plt.show()
# Out:
# <AxesSubplot:xlabel='reviewerID'>
# Text(0.5, 1.0, 'Top 5 reviewerID according to products purchase')
# Text(0.5, 0, 'User Id')
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'A3W11493KS6Z2L'),
#   Text(1, 0, 'ALJ66O1Y6SLHA'),
#   Text(2, 0, 'A3I8S99J38ODC3'),
#   Text(3, 0, 'A3IDT5LC91YJJU'),
#   Text(4, 0, 'A27QAEYVW0V5FC')])

# %%
print('\n No of rated product more than 5 per user : {}\n'.format(sum(products_rated_per_user >= 5)) )
# Out:
#  No of rated product more than 5 per user : 2

# %%
#Getting the new dataframe which contains users who has given 3 or more ratings

new_df=Amazon_F.groupby("asin").filter(lambda x:x['overall'].count() >=5.0)

# %%
new_df
# Out:
#        overall  verified   reviewTime      reviewerID        asin  \
# 0            5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521
# 1            2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2            4     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3            2      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 4            3     False  07 27, 2014   A89F3LQADZBS5  7106116521
# ...        ...       ...          ...             ...         ...
# 19994        5      True  08 23, 2013  A2I8U2L6ZOLPP9  B000P0X15G
# 19995        5     False  08 22, 2013  A38SLX4EMMLSTL  B000P0X15G
# 19996        5      True  08 21, 2013  A24NGH58L8CWDT  B000P0X15G
# 19997        5      True  08 20, 2013  A1NJ9OSQZOZB02  B000P0X15G
# 19998        5      True  08 20, 2013  A2Y39N7FDHEPNY  B000P0X15G
#
#           reviewerName                                         reviewText  \
# 0                Tracy                             Exactly what I needed.
# 1            Sonja Lau  I agree with the other review, the opening is ...
# 2             Kathleen  Love these... I am going to order another pack...
# 3          Jodi Stoner                                too tiny an opening
# 4         Alexander D.                                               Okay
# ...                ...                                                ...
# 19994          Hmama65  My son and daughter-in -law were vacationing i...
# 19995               LC  We loved this hat. Baby looked super cute but ...
# 19996   Veronica Jones  I love the drawstring and the chin tie. Both m...
# 19997  argentinamazing  I got it for my 6 months old. He wore it all s...
# 19998       Bubble Gum  My daughter is 5 months and so I purchase clot...
#
#                                                  summary  unixReviewTime  vote
# 0                                 perfect replacements!!      1413763200   NaN
# 1      I agree with the other review, the opening is ...      1411862400   3.0
# 2                                    My New 'Friends' !!      1408924800   NaN
# 3                                              Two Stars      1408838400   NaN
# 4                                            Three Stars      1406419200   NaN
# ...                                                  ...             ...   ...
# 19994                             Awesome Sun Protection      1377216000   NaN
# 19995                                          Great hat      1377129600   NaN
# 19996                                  Great fitting hat      1377043200   NaN
# 19997                                              Great      1376956800   NaN
# 19998                                          Great hat      1376956800   NaN
#
# [19897 rows x 10 columns]

# %%
no_of_ratings_per_product = new_df.groupby(by='reviewerID')['overall'].count().sort_values(ascending=False)

fig = plt.figure(figsize=plt.figaspect(.5))
ax = plt.gca()
plt.plot(no_of_ratings_per_product.values)
plt.title('# RATINGS per Product')
plt.xlabel('Product')
plt.ylabel('No of ratings per product')
ax.set_xticklabels([])

plt.show()
# Out:
# Text(0.5, 1.0, '# RATINGS per Product')
# Text(0.5, 0, 'Product')
# Text(0, 0.5, 'No of ratings per product')
# [Text(-2500.0, 0, ''),
#  Text(0.0, 0, ''),
#  Text(2500.0, 0, ''),
#  Text(5000.0, 0, ''),
#  Text(7500.0, 0, ''),
#  Text(10000.0, 0, ''),
#  Text(12500.0, 0, ''),
#  Text(15000.0, 0, ''),
#  Text(17500.0, 0, ''),
#  Text(20000.0, 0, '')]

# %% [markdown]
# ###   { Build Popularity Recommender}

# %% [markdown]
# new_df.groupby('reviewerID')['overall'].mean().head()  # Mean rating and reviewer Id

# %%
new_df.groupby('reviewerID')['overall'].mean().sort_values(ascending=False).head()   # mean in ascending order
# Out:
# reviewerID
# A2VU4R4LEAIRDJ    5.0
# A38VNVZYXTLZD5    5.0
# A38T01E8GIJDTD    5.0
# A38T6KN3DAWIII    5.0
# A38TBMV6A586PU    5.0
# Name: overall, dtype: float64

# %%
new_df.groupby('reviewerID')['overall'].count().sort_values(ascending=False).head()   # finding the count
# Out:
# reviewerID
# ALJ66O1Y6SLHA     5
# A3W11493KS6Z2L    5
# A3IDT5LC91YJJU    4
# A1C1NHT2ZZ5A4B    4
# A27QAEYVW0V5FC    4
# Name: overall, dtype: int64

# %%
ratings_mean_count = pd.DataFrame(new_df.groupby('reviewerID')['overall'].mean())

# %%
ratings_mean_count['rating_counts'] = pd.DataFrame(new_df.groupby('reviewerID')['overall'].count())  # calculating the ratings_count

# %%
ratings_mean_count.head()
# Out:
#                       overall  rating_counts
# reviewerID
# A0190232T5E5IGR0GBDU      4.0              1
# A0563004B08RY71KX411      3.0              1
# A0650961HO7RGHL0IRPI      4.0              1
# A1004HHMSDY5IP            3.0              1
# A1009NEF74OBYG            1.0              1

# %%
ratings_mean_count['rating_counts'].max()
# Out:
# 5

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['rating_counts'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['overall'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
sns.jointplot(x='overall', y='rating_counts', data=ratings_mean_count, alpha=0.4,hue='overall')

# %%
popular_products = pd.DataFrame(new_df.groupby('reviewerID')['overall'
                                                            ].count())
most_popular = popular_products.sort_values('overall', ascending=False)
most_popular.head(30).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='reviewerID'>

# %% [markdown]
# ### Filtering on basis of Collaberative Item Wise Recommendation MODEL II

# %%
conda install -c conda-forge scikit-surprise # surprise package comes with scikit for recommendation systems

# %%
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split

# %%
new_df1 = new_df[['reviewerID','asin', 'overall']]
new_df1
# Out:
#            reviewerID        asin  overall
# 0      A1D4G1SNUZWQOT  7106116521        5
# 1      A3DDWDH9PX2YX2  7106116521        2
# 2      A2MWC41EW7XL15  7106116521        4
# 3      A2UH2QQ275NV45  7106116521        2
# 4       A89F3LQADZBS5  7106116521        3
# ...               ...         ...      ...
# 19994  A2I8U2L6ZOLPP9  B000P0X15G        5
# 19995  A38SLX4EMMLSTL  B000P0X15G        5
# 19996  A24NGH58L8CWDT  B000P0X15G        5
# 19997  A1NJ9OSQZOZB02  B000P0X15G        5
# 19998  A2Y39N7FDHEPNY  B000P0X15G        5
#
# [19897 rows x 3 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(new_df1,reader)

# %%
#Splitting the dataset
trainset, testset = train_test_split(data, test_size=0.3,random_state=10)
trainset 
#testset

# %%
algo = KNNWithMeans(k=5, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A3HMKQDPCNWPD5', iid='B00062NHH0', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1DUCI9JPAGX2E', iid='B000NBIMG0', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2W1XAKVSYT0CL', iid='B000EE1NNA', r_ui=3.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A161498ITHE630', iid='B000NBIMG0', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3NBEAP8PK8DVN', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AXI8WKOOY4TLW', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A312P4Y6WJ317Z', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A23WU76UOAEMJE', iid='B000NBIMG0', r_ui=2.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AKCXX4RSR0BJ', iid='B0002PR25Y', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A10C3C96GQ9GQ6', iid='B000K2PJ4K', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2HAAZ4MWABPSU', iid='B000P0X15G', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BUK68G0MECI', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BYGJY1CIVTPY', iid='B000LKETU6', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AYM682WYGPR4X', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A44JHA7T6FS5I', iid='B000P0X15G', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3KGCB3KEJICU8', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A30VRAZST595R6', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LOXURZ0Y3B7H', iid='B000KPIHQ4', r_ui=4.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A263QGBWVXETJF', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A279FUSOD3CYPO', iid='B000ER9V68', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3LHTSGOXYK5PA', iid='B000K2PJ4K', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2FRTXJ0MSIQ2D', iid='B000BD7SGK', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1KIYZCEQEU5KV', iid='B000JOOR7O', r_ui=4.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3W11493KS6Z2L', iid='B000K2PJ4K', r_ui=5.0, est=4.0, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A2GGFJFKDCIJ48', iid='B000P0X15G', r_ui=3.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A5EBGO3XO9J32', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AL33KEMFUE9OZ', iid='B000P0X15G', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AG787IW7MTC4V', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1WA3S2QZ30CEM', iid='B000JOOR7O', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BPBV810I2IXK', iid='B00063VWTY', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A21BM4WI9IRBFP', iid='B000K2PJ4K', r_ui=4.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2TLT2QGCUH2J5', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3R7F1FUPO8CLA', iid='B000E3AUIA', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A108RE198BZZ7P', iid='B000JOOR7O', r_ui=3.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2UIZL69MMDTCS', iid='B000IUX7U2', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1N5HSVJGPKUZ8', iid='B000JOOR7O', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3U0UMB81EBRMN', iid='B00062NHH0', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2CFDYTCCQWQIF', iid='B000OI56VG', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A
details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A33OTWUWEOJPOK', iid='B000P0X15G', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A19OTDTEIV63DK', iid='B000P0X15G', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IK9QWQ3ICBMW', iid='B000NGJ41W', r_ui=4.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37MONG0UV6YG4', iid='B0006HB4XE', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3BAHCUB3JH9WX', iid='B000F4KPIS', r_ui=4.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AN5KMMOS38J1B', iid='B000GHRZN2', r_ui=4.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...
#  Prediction(uid='ALLFQEQ9E6L5Q', iid='B000KPIHQ4', r_ui=2.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2LOFTZG0Z2M5C', iid='B0007MV6Q8', r_ui=3.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3RPV1XFABCZ0L', iid='B00062NHH0', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AJ5TEDPXW9E3M', iid='B000GHMRLW', r_ui=4.0, est=4.035614604462475, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A19QP37L3ZIL55', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13MJ7RCG1G64W', iid='B000ER9V68', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BXOAJFZDLYFR', iid='B000AL4RXA', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A14JQU8FGOK2HF', iid='B0008F6WMM', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3R7C5USIRPFI9', iid='B00063VWTY', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2OGT2DCZFDD0J', iid='B000JOOR7O', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1B2RUAWFMYWVA', iid='B000G01UBW', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ANYOPRFXHRC4Q', iid='B000P0X15G', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2V97X6D17BKS', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AOF4472T6UKBO', iid='B000ER9V68', r_ui=3.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3GPQDKSKOUC23', iid='B00062NHH0', r_ui=3.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1XJAPE1VTVKFI', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AV2YFDKLGADS9', iid='B000HQ4P9O', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AQQ0U3IG6ZJR9', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3S0NJ8MT42O79', iid='B000ML9S14', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AGL7W4HEWNGXZ', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6AU8VM2NTE17', iid='B000NBIMG0', r_ui=3.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2G9QY66VUW0H2', iid='B000P0X15G', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3J673RMCTHONB', iid='B000EE1NNA', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2C1XDIP9OQH5V', iid='B000EE1NNA', r_ui=3.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2X9R6TEHRQMNO', iid='B000LKETU6', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A6ILLZ8Y16XZV', iid='B000K2PJ4K', r_ui=4.0, est=4.0, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A137T3GBZZ1UMD', iid='B00062NHH0', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2Z4AMMDGF6LAK', iid='B000P0X15G', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A12UIGDP6JZB34', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3F4Y6VLM65ENP', iid='B00007GDFV', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ATVAXMCSYVATX', iid='B000GHRZN2', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A7TEFO5ZI0FZ9', iid='B000GHRZN2', r_ui=3.0, est=2.9643853955375246, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1SBKQ6NRLZKG7', iid='B00062NHH0', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1GJBIRDCYVYAB', iid='B00062NHH0', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1BEVAYG6ZYKQO', iid='B000JOOR7O', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1X0ECE995LY1N', iid='B000JOOR7O', r_ui=3.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3JRKJTLXOVZYY', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2I41D6YOK8083', iid='B000NBIMG0', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BI84KQSRLZZ1', iid='B00062NHH0', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AW8CIYHIIM9ZJ', iid='B000P0X15G', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A3IP0RNBYWN6KM', iid='B000KPIHQ4', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1QRKOBN9GO0K8', iid='B0006V9HI4', r_ui=4.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A37E0K123HDUS4', iid='B00062NHH0', r_ui=4.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2BNEBWXJ0OT4D', iid='B000JOOR7O', r_ui=1.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AUNS6AV3644Q3', iid='B000P0X15G', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='
0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A2IPIRM4F5L1UX', iid='B000K2PJ4K', r_ui=3.0, est=4.0, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2DKFHMYVWMU0T', iid='B000GHRZN2', r_ui=4.0, est=3.9643853955375246, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A35TSUEZCGR51A', iid='B000K2PJ4K', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A13IK3H7HR9TJ2', iid='B000P0X15G', r_ui=5.0, est=4.296905291879084, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A1F5RPIVU9TZ7V', iid='B000GHMRLW', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  ...]

# %%
# get RMSE
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 1.0951
# 1.0951133419480084

# %% [markdown]
# ### Build User Based Collaborative Filtering model- Model Based Approach ModelIII

# %%
new_df1=new_df.head(10000)
ratings_matrix = new_df1.pivot_table(values='overall', index='reviewerID', columns='asin', fill_value=0)
ratings_matrix.head()
# Out:
# asin                  7106116521  B00007GDFV  B00008JOQI  B00008JPRZ  \
# reviewerID
# A0190232T5E5IGR0GBDU           0           0           0           0
# A0650961HO7RGHL0IRPI           0           0           0           0
# A1004HHMSDY5IP                 0           0           0           0
# A1009NEF74OBYG                 0           0           0           0
# A100WAE3LAZOE6                 0           0           0           0
#
# asin                  B00008JQF0  B00008JVTT  B0000AWHAA  B0000AWXMM  \
# reviewerID
# A0190232T5E5IGR0GBDU           0           0           0           0
# A0650961HO7RGHL0IRPI           0           0           0           0
# A1004HHMSDY5IP                 0           0           0           0
# A1009NEF74OBYG                 0           0           0           0
# A100WAE3LAZOE6                 0           0           0           0
#
# asin                  B00015VKT4  B0002L2LGI  ...  B000HOGHMO  B000HQ4P9O  \
# reviewerID                                    ...
# A0190232T5E5IGR0GBDU           0           0  ...           0           0
# A0650961HO7RGHL0IRPI           0           0  ...           0           0
# A1004HHMSDY5IP                 0           0  ...           0           0
# A1009NEF74OBYG                 0           0  ...           0           0
# A100WAE3LAZOE6                 0           0  ...           0           0
#
# asin                  B000HR77R0  B000HSTWY0  B000I5N5OK  B000IF0XQS  \
# reviewerID
# A0190232T5E5IGR0GBDU           0           0           0           0
# A0650961HO7RGHL0IRPI           0           0           0           0
# A1004HHMSDY5IP                 0           0           0           0
# A1009NEF74OBYG                 0           0           0           0
# A100WAE3LAZOE6                 0           0           0           0
#
# asin                  B000IUX7U2  B000J3ROES  B000JOOR7O  B000JPPOZ2
# reviewerID
# A0190232T5E5IGR0GBDU           0           0         4.0           0
# A0650961HO7RGHL0IRPI           0           0         0.0           0
# A1004HHMSDY5IP                 0           0         0.0           0
# A1009NEF74OBYG                 0           0         1.0           0
# A100WAE3LAZOE6                 0           0         0.0           0
#
# [5 rows x 77 columns]

# %%
# Define reviewer index from 0 to 10
ratings_matrix['user_index'] = np.arange(0, ratings_matrix.shape[0], 1)
ratings_matrix.head()
# Out:
# asin                  7106116521  B00007GDFV  B00008JOQI  B00008JPRZ  \
# reviewerID
# A0190232T5E5IGR0GBDU           0           0           0           0
# A0650961HO7RGHL0IRPI           0           0           0           0
# A1004HHMSDY5IP                 0           0           0           0
# A1009NEF74OBYG                 0           0           0           0
# A100WAE3LAZOE6                 0           0           0           0
#
# asin                  B00008JQF0  B00008JVTT  B0000AWHAA  B0000AWXMM  \
# reviewerID
# A0190232T5E5IGR0GBDU           0           0           0           0
# A0650961HO7RGHL0IRPI           0           0           0           0
# A1004HHMSDY5IP                 0           0           0           0
# A1009NEF74OBYG                 0           0           0           0
# A100WAE3LAZOE6                 0           0           0           0
#
# asin                  B00015VKT4  B0002L2LGI  ...  B000HQ4P9O  B000HR77R0  \
# reviewerID                                    ...
# A0190232T5E5IGR0GBDU           0           0  ...           0           0
# A0650961HO7RGHL0IRPI           0           0  ...           0           0
# A1004HHMSDY5IP                 0           0  ...           0           0
# A1009NEF74OBYG                 0           0  ...           0           0
# A100WAE3LAZOE6                 0           0  ...           0           0
#
# asin                  B000HSTWY0  B000I5N5OK  B000IF0XQS  B000IUX7U2  \
# reviewerID
# A0190232T5E5IGR0GBDU           0           0           0           0
# A0650961HO7RGHL0IRPI           0           0           0           0
# A1004HHMSDY5IP                 0           0           0           0
# A1009NEF74OBYG                 0           0           0           0
# A100WAE3LAZOE6                 0           0           0           0
#
# asin                  B000J3ROES  B000JOOR7O  B000JPPOZ2  user_index
# reviewerID
# A0190232T5E5IGR0GBDU           0         4.0           0           0
# A0650961HO7RGHL0IRPI           0         0.0           0           1
# A1004HHMSDY5IP                 0         0.0           0           2
# A1009NEF74OBYG                 0         1.0           0           3
# A100WAE3LAZOE6                 0         0.0           0           4
#
# [5 rows x 78 columns]

# %%
# Finding the shape 
ratings_matrix.shape
# Out:
# (8558, 78)

# %%
# Transposing the matrix 
X = ratings_matrix.T
X.head()
# Out:
# reviewerID  A0190232T5E5IGR0GBDU  A0650961HO7RGHL0IRPI  A1004HHMSDY5IP  \
# asin
# 7106116521                   0.0                   0.0             0.0
# B00007GDFV                   0.0                   0.0             0.0
# B00008JOQI                   0.0                   0.0             0.0
# B00008JPRZ                   0.0                   0.0             0.0
# B00008JQF0                   0.0                   0.0             0.0
#
# reviewerID  A1009NEF74OBYG  A100WAE3LAZOE6  A1019GAOMX6BGY  A1021P7FVGP7FA  \
# asin
# 7106116521             0.0             0.0             0.0             0.0
# B00007GDFV             0.0             0.0             0.0             0.0
# B00008JOQI             0.0             0.0             0.0             0.0
# B00008JPRZ             0.0             0.0             0.0             0.0
# B00008JQF0             0.0             0.0             0.0             0.0
#
# reviewerID  A1037D806EY3SL  A104042GV5EM0U  A104GTX4GP75L1  ...  \
# asin                                                        ...
# 7106116521             0.0             0.0             0.0  ...
# B00007GDFV             0.0             0.0             0.0  ...
# B00008JOQI             0.0             0.0             0.0  ...
# B00008JPRZ             0.0             0.0             0.0  ...
# B00008JQF0             0.0             0.0             0.0  ...
#
# reviewerID  AZVGOQYV4QR6J  AZVPLKOTY7QWU  AZVRKS8DMISM0  AZWDI8J58WQFW  \
# asin
# 7106116521            0.0            0.0            0.0            0.0
# B00007GDFV            0.0            0.0            0.0            0.0
# B00008JOQI            0.0            0.0            0.0            0.0
# B00008JPRZ            0.0            0.0            0.0            0.0
# B00008JQF0            0.0            0.0            0.0            0.0
#
# reviewerID  AZXHS2CNCF3PO  AZXMEWZMRYAXF  AZYFPB15N5EB5  AZYIBG912W011  \
# asin
# 7106116521            0.0            0.0            0.0            0.0
# B00007GDFV            0.0            0.0            0.0            0.0
# B00008JOQI            0.0            0.0            0.0            0.0
# B00008JPRZ            0.0            0.0            0.0            0.0
# B00008JQF0            0.0            0.0            0.0            0.0
#
# reviewerID  AZZ7YP08I4OZ6  AZZKYP9254H32
# asin
# 7106116521            0.0            0.0
# B00007GDFV            0.0            0.0
# B00008JOQI            0.0            0.0
# B00008JPRZ            0.0            0.0
# B00008JQF0            0.0            0.0
#
# [5 rows x 8558 columns]

# %%
X.shape
# Out:
# (78, 8558)

# %%
X1 = X
X1
# Out:
# reviewerID  A0190232T5E5IGR0GBDU  A0650961HO7RGHL0IRPI  A1004HHMSDY5IP  \
# asin
# 7106116521                   0.0                   0.0             0.0
# B00007GDFV                   0.0                   0.0             0.0
# B00008JOQI                   0.0                   0.0             0.0
# B00008JPRZ                   0.0                   0.0             0.0
# B00008JQF0                   0.0                   0.0             0.0
# ...                          ...                   ...             ...
# B000IUX7U2                   0.0                   0.0             0.0
# B000J3ROES                   0.0                   0.0             0.0
# B000JOOR7O                   4.0                   0.0             0.0
# B000JPPOZ2                   0.0                   0.0             0.0
# user_index                   0.0                   1.0             2.0
#
# reviewerID  A1009NEF74OBYG  A100WAE3LAZOE6  A1019GAOMX6BGY  A1021P7FVGP7FA  \
# asin
# 7106116521             0.0             0.0             0.0             0.0
# B00007GDFV             0.0             0.0             0.0             0.0
# B00008JOQI             0.0             0.0             0.0             0.0
# B00008JPRZ             0.0             0.0             0.0             0.0
# B00008JQF0             0.0             0.0             0.0             0.0
# ...                    ...             ...             ...             ...
# B000IUX7U2             0.0             0.0             0.0             0.0
# B000J3ROES             0.0             0.0             0.0             0.0
# B000JOOR7O             1.0             0.0             0.0             0.0
# B000JPPOZ2             0.0             0.0             0.0             0.0
# user_index             3.0             4.0             5.0             6.0
#
# reviewerID  A1037D806EY3SL  A104042GV5EM0U  A104GTX4GP75L1  ...  \
# asin                                                        ...
# 7106116521             0.0             0.0             0.0  ...
# B00007GDFV             0.0             0.0             0.0  ...
# B00008JOQI             0.0             0.0             0.0  ...
# B00008JPRZ             0.0             0.0             0.0  ...
# B00008JQF0             0.0             0.0             0.0  ...
# ...                    ...             ...             ...  ...
# B000IUX7U2             0.0             0.0             0.0  ...
# B000J3ROES             0.0             0.0             0.0  ...
# B000JOOR7O             0.0             0.0             0.0  ...
# B000JPPOZ2             0.0             0.0             0.0  ...
# user_index             7.0             8.0             9.0  ...
#
# reviewerID  AZVGOQYV4QR6J  AZVPLKOTY7QWU  AZVRKS8DMISM0  AZWDI8J58WQFW  \
# asin
# 7106116521            0.0            0.0            0.0            0.0
# B00007GDFV            0.0            0.0            0.0            0.0
# B00008JOQI            0.0            0.0            0.0            0.0
# B00008JPRZ            0.0            0.0            0.0            0.0
# B00008JQF0            0.0            0.0            0.0            0.0
# ...                   ...            ...            ...            ...
# B000IUX7U2            0.0            0.0            0.0            0.0
# B000J3ROES            0.0            0.0            0.0            0.0
# B000JOOR7O            0.0            0.0            0.0            5.0
# B000JPPOZ2            0.0            0.0            0.0            0.0
# user_index         8548.0         8549.0         8550.0         8551.0
#
# reviewerID  AZXHS2CNCF3PO  AZXMEWZMRYAXF  AZYFPB15N5EB5  AZYIBG912W011  \
# asin
# 7106116521            0.0            0.0            0.0            0.0
# B00007GDFV            0.0            0.0            0.0            0.0
# B00008JOQI            0.0            0.0            0.0            0.0
# B00008JPRZ            0.0            0.0            0.0            0.0
# B00008JQF0            0.0            0.0            0.0            0.0
# ...                   ...            ...            ...            ...
# B000IUX7U2            0.0            0.0            0.0            0.0
# B000J3ROES            0.0            0.0            0.0            0.0
# B000JOOR7O            0.0            0.0            0.0            0.0
# B000JPPOZ2            0.0            0.0            0.0            0.0
# user_index         8552.0         8553.0         8554.0         8555.0
#
# reviewerID  AZZ7YP08I4OZ6  AZZKYP9254H32
# asin
# 7106116521            0.0            0.0
# B00007GDFV            0.0            0.0
# B00008JOQI            0.0            0.0
# B00008JPRZ            0.0            0.0
# B00008JQF0            0.0            0.0
# ...                   ...            ...
# B000IUX7U2            0.0            0.0
# B000J3ROES            0.0            0.0
# B000JOOR7O            0.0            5.0
# B000JPPOZ2            0.0            0.0
# user_index         8556.0         8557.0
#
# [78 rows x 8558 columns]

# %%
#Decomposing the Matrix
from sklearn.decomposition import TruncatedSVD
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (78, 10)

# %%
#Correlation Matrix

correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (78, 78)

# %%
#Correlation Matrix

X.index[75]
# Out:
# 'B000JOOR7O'

# %%
i = "B000EB3RXM"

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 49

# %%
#Correlation for all items with the item purchased by this customer based on items rated by other customers people who bought the same product

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (78,)

# %%
Recommend = list(X.index[correlation_product_ID > 0.65])

# Removes the item already bought by the customer
Recommend.remove(i) 

Recommend[0:24]
# Out:
# ['7106116521',
#  'B00007GDFV',
#  'B00008JOQI',
#  'B00008JPRZ',
#  'B00008JQF0',
#  'B00008JVTT',
#  'B0000AWHAA',
#  'B0000AWXMM',
#  'B00015VKT4',
#  'B0002L2LGI',
#  'B0002PR25Y',
#  'B0002TGUU8',
#  'B0002UQASO',
#  'B0002Z1JNK',
#  'B00061RG3M',
#  'B00063VWSA',
#  'B00063VWTY',
#  'B00066G516',
#  'B000673JT6',
#  'B0006FUF68',
#  'B0006FYTWY',
#  'B0006HB4W0',
#  'B0006IXEG8',
#  'B0006Q3Q4A']

# %%
#References:
 
    #Cannot install scikit-surprise on my jupyter notebook. (2020, May 27). Stack Overflow. https://stackoverflow.com/questions/62042317/cannot-install-scikit-surprise-on-my-jupyter-notebook
    #ImportError in importing from sklearn: cannot import name check_build. (2013, March 7). Stack Overflow. https://stackoverflow.com/questions/15274696/importerror-in-importing-from-sklearn-cannot-import-name-check-build

# %%
# References

#Evaluating Prediction Accuracy for Collaborative Filtering Algorithms in Recommender Systems
